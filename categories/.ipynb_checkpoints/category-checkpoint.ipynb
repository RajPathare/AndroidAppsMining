# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../dataset/education.csv')

# %%
len(df)
# Out:
# 500

# %%
df1=df[df.score<=3.5]

# %%
len(df1)
# Out:
# 51

# %%
text = " ".join(review for review in df1.description)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 73669 words in the combination of all review.

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize=(8,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
wordcloud.to_file("../pics/education/Lowrated.png")

# %%
df.corr(method="spearman")
# Out:
#                 screenshots     score   reviews  editors_choice      free  \
# screenshots        1.000000 -0.025339  0.381686        0.091602 -0.146283
# score             -0.025339  1.000000 -0.148967        0.034526  0.118533
# reviews            0.381686 -0.148967  1.000000        0.290508  0.101000
# editors_choice     0.091602  0.034526  0.290508        1.000000  0.051885
# free              -0.146283  0.118533  0.101000        0.051885  1.000000
# iap                0.243005 -0.035710  0.452991        0.188446  0.352878
# installs           0.381007 -0.241091  0.938313        0.266574  0.174031
#
#                      iap  installs
# screenshots     0.243005  0.381007
# score          -0.035710 -0.241091
# reviews         0.452991  0.938313
# editors_choice  0.188446  0.266574
# free            0.352878  0.174031
# iap             1.000000  0.435763
# installs        0.435763  1.000000
