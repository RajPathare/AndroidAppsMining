# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/education.csv',index_col=0)

# %%
print(len(df))
df.head()
# Out:
# 500
#                                                                                            icon  \
# title
# ABC Preschool Free                            https://lh3.googleusercontent.com/uzI07D7lLwXc...
# History Channel : Best Documentaries          https://lh3.googleusercontent.com/OcRVW1TXoxrQ...
# CuriosityStream - Watch Documentaries Online  https://lh3.googleusercontent.com/OKDS68ssZR6G...
# Pearson eText                                 https://lh3.googleusercontent.com/IINCgeuyd-R0...
# Khan Academy Kids (BETA)                      https://lh3.googleusercontent.com/BaMh_9XyAIt5...
#
#                                               screenshots  \
# title
# ABC Preschool Free                                     21
# History Channel : Best Documentaries                   12
# CuriosityStream - Watch Documentaries Online           14
# Pearson eText                                           8
# Khan Academy Kids (BETA)                               15
#
# ...

# %%
df.corr()
# Out:
#                 screenshots         score   reviews  editors_choice      free  \
# screenshots        1.000000  5.725358e-02  0.172996        0.093192 -0.142364
# score              0.057254  1.000000e+00  0.066216        0.064700  0.082590
# reviews            0.172996  6.621596e-02  1.000000        0.440542  0.161436
# editors_choice     0.093192  6.469999e-02  0.440542        1.000000  0.051885
# free              -0.142364  8.258971e-02  0.161436        0.051885  1.000000
# iap                0.241189  3.242338e-02  0.244939        0.188446  0.352878
# installs           0.201508 -9.402764e-07  0.752235        0.343464  0.193361
#
#                      iap      installs
# screenshots     0.241189  2.015078e-01
# score           0.032423 -9.402764e-07
# reviews         0.244939  7.522346e-01
# editors_choice  0.188446  3.434638e-01
# free            0.352878  1.933607e-01
# iap             1.000000  2.450375e-01
# installs        0.245038  1.000000e+00

# %%
rev=[]
for i in df['reviews']:
    rev.append(i)

# %%
len(df[df.reviews >=1000])
df5=df[df.reviews >=1000]

# %%
score=[]
for i in df['score']:
    score.append(i)

# %%
print(score)
# Out:
# [3.8, 4.3, 4.1, 2.3, 4.5, 4.5, 4.1, 4.0, 4.3, 3.7, 4.8, 4.3, 2.2, 4.3, 4.4, 4.5, 4.5, 3.9, 3.9, 4.4, 4.3, 4.5, 4.3, 3.6, 2.0, 3.0, 1.4, 4.5, 4.5, 4.0, 4.4, 4.3, 3.6, 4.4, 4.3, 4.1, 4.3, 4.6, 4.1, 2.8, 4.5, 4.4, 4.7, 4.2, 4.7, 4.3, 4.8, 4.2, 4.0, 1.7, 4.5, 3.3, 4.7, 3.8, 3.0, 4.4, 4.9, 4.2, 4.6, 4.7, 4.6, 4.6, 4.3, 4.4, 4.0, 4.4, 4.3, 4.2, 4.3, 4.7, 4.5, 4.5, 4.4, 3.4, 4.7, 4.3, 4.4, 3.5, 4.3, 4.5, 3.8, 4.1, 4.5, 4.5, 4.4, 3.7, 2.5, 2.1, 4.1, 4.3, 4.5, 3.2, 4.3, 4.4, 4.1, 4.5, 4.8, 4.8, 4.6, 4.4, 3.5, 4.0, 4.4, 4.3, 3.1, 3.8, 5.0, 4.1, 4.4, 4.5, 3.3, 4.9, 4.1, 1.8, 4.2, 4.7, 4.1, 4.5, 4.2, 4.1, 3.9, 4.7, 4.5, 2.2, 4.7, nan, 4.3, 4.7, 3.1, 4.6, 4.1, nan, 4.5, 4.2, 3.7, 4.6, 4.8, 4.3, 3.8, 4.7, 4.2, 4.1, 3.9, 4.2, 3.7, 4.5, 4.3, 4.0, 5.0, 4.3, 4.6, 4.8, 4.5, 4.6, 4.1, 4.7, 4.4, 3.7, 5.0, 4.2, 4.2, 4.8, 4.0, 4.0, 4.1, 4.7, 5.0, 4.1, 4.7, 4.2, 3.6, 3.8, 4.7, 1.6, 4.4, 3.7, 4.2, 4.6, 4.5, 4.8, 4.3, 3.7, 4.6, 5.0, 3.7, 3.4, 4.4, 4.7, 4.6, 4.7, 4.9, 4.4, 3.7, 4.4, 3.2, 4.6, 4.6, 4.4, 4.5, 4.
# ...

# %%
plt.plot(score,rev)

# %%
df=df.drop_duplicates(keep='first')

# %%
print(len(df))
# Out:
# 492

# %%
score=[]
for i in df['score']:
    score.append(i)

# %%
rev=[]
for i in df['reviews']:
    rev.append(i)

# %%
plt.plot(score,rev)

# %%
df['iap'].corr(df['score'])
# Out:
# 0.02802269540338297

# %%
df.corr(method='spearman')
# Out:
#                 screenshots     score   reviews  editors_choice      free  \
# screenshots        1.000000 -0.036583  0.389689        0.090225 -0.148850
# score             -0.036583  1.000000 -0.144645        0.032073  0.115924
# reviews            0.389689 -0.144645  1.000000        0.293108  0.097102
# editors_choice     0.090225  0.032073  0.293108        1.000000  0.052951
# free              -0.148850  0.115924  0.097102        0.052951  1.000000
# iap                0.247792 -0.040989  0.454501        0.189995  0.353325
# installs           0.388904 -0.236444  0.938026        0.270025  0.169773
#
#                      iap  installs
# screenshots     0.247792  0.388904
# score          -0.040989 -0.236444
# reviews         0.454501  0.938026
# editors_choice  0.189995  0.270025
# free            0.353325  0.169773
# iap             1.000000  0.438495
# installs        0.438495  1.000000

# %%
df5['installs']
# Out:
# title
# ABC Preschool Free                                     5000000
# CuriosityStream - Watch Documentaries Online            100000
# Pearson eText                                           100000
# Spanish Lucas' Whiteboard                              1000000
# busuu: Learn Languages - Spanish, English & More      10000000
# Here Comes the Bus                                      100000
# Snappy Comebacks                                         50000
# Star Tracker - Mobile Sky Map                          1000000
# Kids Coloring Book                                     1000000
# Cymath - Math Problem Solver                           1000000
# How to Get Anything You Want                            500000
# IXL                                                    1000000
# Starfall Learn to Read                                  500000
# Multiplication Tables Learn                             500000
# Princess Coloring Book                                 5000000
# ...

# %%
len(df5[df5.installs >=1000])
df6=df5[df5.reviews >=50000]

# %%
len(df6)
# Out:
# 10

# %%
df6.corr(method="spearman")
# Out:
#                 screenshots     score   reviews  editors_choice  free  \
# screenshots        1.000000  0.185185  0.012233       -0.466192   NaN
# score              0.185185  1.000000  0.342522       -0.824802   NaN
# reviews            0.012233  0.342522  1.000000        0.000000   NaN
# editors_choice    -0.466192 -0.824802  0.000000        1.000000   NaN
# free                    NaN       NaN       NaN             NaN   NaN
# iap                0.143444 -0.573775  0.142134        0.583333   NaN
# installs           0.185924 -0.358569  0.605316        0.462910   NaN
#
#                      iap  installs
# screenshots     0.143444  0.185924
# score          -0.573775 -0.358569
# reviews         0.142134  0.605316
# editors_choice  0.583333  0.462910
# free                 NaN       NaN
# iap             1.000000  0.462910
# installs        0.462910  1.000000

# %%
rev=[]
for i in df6['reviews']:
    rev.append(i)

# %%
score=[]
for i in df6['score']:
    score.append(i)

# %%
plt.plot(rev, score)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
