# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/entern-new.csv',index_col=0)

# %%
df.head()
# Out:
#                                                                             icon  \
# title
# Pranitha Subhash Official App  https://lh3.googleusercontent.com/4ukSvKt-Fr7n...
# T20 Cricket Games              https://lh3.googleusercontent.com/N-keXoEyNGzh...
# Radio FM 2018                  https://lh3.googleusercontent.com/sOupUS49rbSb...
# My Live Tv                     https://lh3.googleusercontent.com/3eACzJdVLhu9...
# giftmoney                      https://lh3.googleusercontent.com/O9nX7Bq4bZSl...
#
#                                screenshots video           category  score  \
# title
# Pranitha Subhash Official App            9   NaN  ['ENTERTAINMENT']    4.4
# T20 Cricket Games                        4   NaN  ['ENTERTAINMENT']    5.0
# Radio FM 2018                            5   NaN  ['ENTERTAINMENT']    4.8
# My Live Tv                               5   NaN  ['ENTERTAINMENT']    3.6
# giftmoney                                3   NaN  ['ENTERTAINMENT']    3.9
#
# ...

# %%
len(df)
# Out:
# 400

# %%
df2=pd.read_csv('dataset/entern-raj.csv')

# %%
len(df2)
# Out:
# 101

# %%
df3=df.append(df2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
len(df3)
# Out:
# 501

# %%
df3.head()
# Out:
#                               Unnamed: 0                              app_id  \
# Pranitha Subhash Official App        NaN            escapemusic.android.a870
# T20 Cricket Games                    NaN     com.fahadsports.t20cricketgames
# Radio FM 2018                        NaN    com.free.all.country.radio.music
# My Live Tv                           NaN             com.app.entertainmenttv
# giftmoney                            NaN  com.firstname333888.hanckgiftmoney
#
#                                         category    content_rating  \
# Pranitha Subhash Official App  ['ENTERTAINMENT']  ['Rated for 3+']
# T20 Cricket Games              ['ENTERTAINMENT']  ['Rated for 3+']
# Radio FM 2018                  ['ENTERTAINMENT']  ['Rated for 3+']
# My Live Tv                     ['ENTERTAINMENT']  ['Rated for 3+']
# giftmoney                      ['ENTERTAINMENT']  ['Rated for 3+']
#
#                               current_version  \
# Pranitha Subhash Official App     1.9300.0001
# ...

# %%
df3.drop_duplicates(keep='first')
# Out:
#                                                                                            Unnamed: 0  \
# Pranitha Subhash Official App                                                                     NaN
# T20 Cricket Games                                                                                 NaN
# Radio FM 2018                                                                                     NaN
# My Live Tv                                                                                        NaN
# giftmoney                                                                                         NaN
# Bigg Boss Tamil - Updates & Vote                                                                  NaN
# Kundali Bhagya Video Status                                                                       NaN
# PUBG Wallpaper-PUBG Background                                                                    NaN
# ...

# %%
len(df3)
# Out:
# 501

# %%
df3.to_csv('dataset/entern-final.csv',encoding='utf-8')

# %%
df4 = pd.read_csv('dataset/lifestyle-final.csv',index_col=0)

# %%
df4.dtypes
# Out:
# icon                         object
# screenshots                   int64
# video                        object
# category                     object
# score                       float64
# histogram                    object
# reviews                       int64
# description                  object
# description_html             object
# recent_changes               object
# editors_choice                 bool
# price                        object
# free                           bool
# iap                            bool
# developer_id                 object
# updated                      object
# size                         object
# installs                      int64
# current_version              object
# required_android_version     object
# content_rating               object
# iap_range                    object
# interactive_elements         object
# developer                    object
# developer_email              object
# developer_url                object
# ...

# %%
df4.corr()
# Out:
#                 screenshots     score   reviews  editors_choice      free  \
# screenshots        1.000000  0.029760  0.033063        0.006616 -0.137858
# score              0.029760  1.000000  0.065337        0.064798  0.138389
# reviews            0.033063  0.065337  1.000000        0.298030  0.092979
# editors_choice     0.006616  0.064798  0.298030        1.000000  0.055446
# free              -0.137858  0.138389  0.092979        0.055446  1.000000
# iap                0.133236 -0.065152  0.147300        0.066726  0.305681
# installs           0.065744  0.035103  0.896294        0.208802  0.085195
#
#                      iap  installs
# screenshots     0.133236  0.065744
# score          -0.065152  0.035103
# reviews         0.147300  0.896294
# editors_choice  0.066726  0.208802
# free            0.305681  0.085195
# iap             1.000000  0.075710
# installs        0.075710  1.000000
