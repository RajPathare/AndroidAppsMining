# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/BUSINESS.csv',index_col=0)

# %%
df.head()
# Out:
#                                                                  icon  \
# title
# India Post Tracker  https://lh3.googleusercontent.com/81-qp8qzvDTa...
# SwissGold Market    https://lh3.googleusercontent.com/iUnCcDdLHjj9...
# InstaPromo          https://lh3.googleusercontent.com/hZzsINL78uxa...
# MITRA - MHADA       https://lh3.googleusercontent.com/6Lss24bCB4kI...
# Visshwa Solutions   https://lh3.googleusercontent.com/xVyt7rwKSAfV...
#
#                     screenshots video      category  score  \
# title
# India Post Tracker            5   NaN  ['BUSINESS']    5.0
# SwissGold Market             11   NaN  ['BUSINESS']    4.9
# InstaPromo                    3   NaN  ['BUSINESS']    5.0
# MITRA - MHADA                 8   NaN  ['BUSINESS']    4.8
# Visshwa Solutions             3   NaN  ['BUSINESS']    5.0
#
#                                           histogram  reviews  \
# title
# India Post Tracker   {5: 2, 4: 0, 3: 0, 2: 0, 1: 0}        2
# ...

# %%
len(df)
# Out:
# 151

# %%
df2 = pd.read_csv('dataset/education.csv',index_col=0)

# %%
len(df2)
# Out:
# 500

# %%
df3=df.append(df2)

# %%
len(df3)
# Out:
# 651

# %%
df4=pd.read_csv('dataset/entern-new.csv',index_col=0)
len(df4)
# Out:
# 400

# %%
df3=df3.append(df4)

# %%
len(df3)
# Out:
# 1051

# %%
df5=pd.read_csv('dataset/lifestyle-final.csv',index_col=0)
len(df5)
# Out:
# 300

# %%
df3=df3.append(df5)
len(df3)
# Out:
# 1351

# %%
df6=pd.read_csv('dataset/pers.csv',index_col=0)
len(df6)
# Out:
# 300

# %%
merge=df3.append(df6)
len(merge)
# Out:
# 1651

# %%
merge.dtypes
# Out:
# icon                         object
# screenshots                   int64
# video                        object
# category                     object
# score                       float64
# histogram                    object
# reviews                       int64
# description                  object
# description_html             object
# recent_changes               object
# editors_choice                 bool
# price                        object
# free                           bool
# iap                            bool
# developer_id                 object
# updated                      object
# size                         object
# installs                      int64
# current_version              object
# required_android_version     object
# content_rating               object
# iap_range                    object
# interactive_elements         object
# developer                    object
# developer_email              object
# developer_url                object
# ...

# %%
df7=pd.read_csv('dataset/trav.csv',index_col=0)
len(df7)
# Out:
# 200

# %%
final=merge.append(df7)
len(final)
# Out:
# 1851

# %%
final.drop_duplicates(keep='first')
len(final)
# Out:
# 1851

# %%
final.to_csv('dataset/final.csv',encoding='utf-8')

# %%
final.corr(method="spearman")
# Out:
#                 screenshots     score   reviews  editors_choice      free  \
# screenshots        1.000000 -0.007876  0.264909        0.073055 -0.102588
# score             -0.007876  1.000000 -0.122070        0.039273  0.043575
# reviews            0.264909 -0.122070  1.000000        0.179717  0.217577
# editors_choice     0.073055  0.039273  0.179717        1.000000  0.060316
# free              -0.102588  0.043575  0.217577        0.060316  1.000000
# iap                0.222217 -0.072103  0.374770        0.091493  0.302087
# installs           0.248981 -0.197896  0.929014        0.166827  0.356075
#
#                      iap  installs
# screenshots     0.222217  0.248981
# score          -0.072103 -0.197896
# reviews         0.374770  0.929014
# editors_choice  0.091493  0.166827
# free            0.302087  0.356075
# iap             1.000000  0.368797
# installs        0.368797  1.000000

# %%
final.price
# Out:
# title
# India Post Tracker                                           0
# SwissGold Market                                             0
# InstaPromo                                                   0
# MITRA - MHADA                                                0
# Visshwa Solutions                                            0
# Great Wallet                                                 0
# MPAYIN                                                       0
# Personal loans - VHNT app                                    0
# SafeShop - Safe and Secure Online Marketing Pvt Lt           0
# MAA                                                          0
# He Min - Make Money, Earn Money                              0
# Aapna Raddiwala                                              0
# Archer Care                                                  0
# Mobile Payments UPI AEPS BBPS PAN CENTER - ADDLEY            0
# Kijiji classifieds canada pix                                0
# ...

# %%
final['new_price'] = final['price'].str.replace('\W', '')

# %%
final['new_price']
# Out:
# title
# India Post Tracker                                        0
# SwissGold Market                                          0
# InstaPromo                                                0
# MITRA - MHADA                                             0
# Visshwa Solutions                                         0
# Great Wallet                                              0
# MPAYIN                                                    0
# Personal loans - VHNT app                                 0
# SafeShop - Safe and Secure Online Marketing Pvt Lt        0
# MAA                                                       0
# He Min - Make Money, Earn Money                           0
# Aapna Raddiwala                                           0
# Archer Care                                               0
# Mobile Payments UPI AEPS BBPS PAN CENTER - ADDLEY         0
# Kijiji classifieds canada pix                             0
# AdzBazar                                                  0
# ...

# %%
final.corr()
# Out:
#                 screenshots     score   reviews  editors_choice      free  \
# screenshots        1.000000  0.021671  0.043352        0.076702 -0.086253
# score              0.021671  1.000000  0.023540        0.043991  0.083960
# reviews            0.043352  0.023540  1.000000        0.065211  0.091221
# editors_choice     0.076702  0.043991  0.065211        1.000000  0.060316
# free              -0.086253  0.083960  0.091221        0.060316  1.000000
# iap                0.225689 -0.010091  0.135116        0.091493  0.302087
# installs           0.020996  0.000378  0.465122        0.017662  0.057360
#
#                      iap  installs
# screenshots     0.225689  0.020996
# score          -0.010091  0.000378
# reviews         0.135116  0.465122
# editors_choice  0.091493  0.017662
# free            0.302087  0.057360
# iap             1.000000  0.038674
# installs        0.038674  1.000000

# %%
final['new_price'].astype(float)
# Out:
# title
# India Post Tracker                                        0.0
# SwissGold Market                                          0.0
# InstaPromo                                                0.0
# MITRA - MHADA                                             0.0
# Visshwa Solutions                                         0.0
# Great Wallet                                              0.0
# MPAYIN                                                    0.0
# Personal loans - VHNT app                                 0.0
# SafeShop - Safe and Secure Online Marketing Pvt Lt        0.0
# MAA                                                       0.0
# He Min - Make Money, Earn Money                           0.0
# Aapna Raddiwala                                           0.0
# Archer Care                                               0.0
# Mobile Payments UPI AEPS BBPS PAN CENTER - ADDLEY         0.0
# Kijiji classifieds canada pix                             0.0
# ...

# %%
final.corr()
# Out:
#                 screenshots     score   reviews  editors_choice      free  \
# screenshots        1.000000  0.021671  0.043352        0.076702 -0.086253
# score              0.021671  1.000000  0.023540        0.043991  0.083960
# reviews            0.043352  0.023540  1.000000        0.065211  0.091221
# editors_choice     0.076702  0.043991  0.065211        1.000000  0.060316
# free              -0.086253  0.083960  0.091221        0.060316  1.000000
# iap                0.225689 -0.010091  0.135116        0.091493  0.302087
# installs           0.020996  0.000378  0.465122        0.017662  0.057360
#
#                      iap  installs
# screenshots     0.225689  0.020996
# score          -0.010091  0.000378
# reviews         0.135116  0.465122
# editors_choice  0.091493  0.017662
# free            0.302087  0.057360
# iap             1.000000  0.038674
# installs        0.038674  1.000000

# %%
final.head()
# Out:
#                                                                  icon  \
# title
# India Post Tracker  https://lh3.googleusercontent.com/81-qp8qzvDTa...
# SwissGold Market    https://lh3.googleusercontent.com/iUnCcDdLHjj9...
# InstaPromo          https://lh3.googleusercontent.com/hZzsINL78uxa...
# MITRA - MHADA       https://lh3.googleusercontent.com/6Lss24bCB4kI...
# Visshwa Solutions   https://lh3.googleusercontent.com/xVyt7rwKSAfV...
#
#                     screenshots video      category  score  \
# title
# India Post Tracker            5   NaN  ['BUSINESS']    5.0
# SwissGold Market             11   NaN  ['BUSINESS']    4.9
# InstaPromo                    3   NaN  ['BUSINESS']    5.0
# MITRA - MHADA                 8   NaN  ['BUSINESS']    4.8
# Visshwa Solutions             3   NaN  ['BUSINESS']    5.0
#
#                                           histogram  reviews  \
# title
# India Post Tracker   {5: 2, 4: 0, 3: 0, 2: 0, 1: 0}        2
# ...
